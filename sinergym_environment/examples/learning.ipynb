# %% [markdown]
# # Basic example

# %% [markdown]
# Sinergym utilizes the standard [Farama Gymnasium API](https://gymnasium.farama.org/index.html). Let's explore how to create a basic loop.
#
# To begin, we need to import Sinergym and create an environment. In this example, we will use the `Eplus-demo-v1` environment.

# %%
# !pip install gymnasium
# !pip install numpy
# !pip install sinergym
# Out:
# Requirement already satisfied: gymnasium in /home/aditya-kumar/.pyenv/versions/3.11.5/lib/python3.11/site-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in /home/aditya-kumar/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from gymnasium) (2.0.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/aditya-kumar/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from gymnasium) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/aditya-kumar/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/aditya-kumar/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from gymnasium) (0.0.4)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: numpy in /home/aditya-kumar/.pyenv/versions/3.11.5/lib/python3.11/site-packages (2.0.1)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Collecting sinergym
#   Downloading sinergym-3.4.0.tar.gz (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 9.4 MB/s eta 0:00:00:00:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting autopep8 (from sinergym)
#   Obtaining dependency information for autopep8 from https://files.pythonhosted.org/packages/ad/9e/f0beffe45b507dca9d7540fad42b316b2fd1076dc484c9b1f23d9da570d7/autopep8-2.3.1-py2.py3-none-any.whl.metadata
#   Downloading autopep8-2.3.1-py2.py3-none-any.whl.metadata (16 kB)
# Collecting eppy (from sinergym)
#   Obtaining dependency information for eppy from https://files.pythonhosted.org/packages/45/d3/949aaad51ff78e5c595e7cef777a3b92e825fa92a64a103216a9718b2ed4/eppy-0.5.63-py2.py3-none-any.whl.metadata
#   Downloading eppy-0.5.63-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: gymnasium in /home/aditya-kumar/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from sinergym) (0.29.1)
# Collecting isort (from sinergym)
#   Obtaining dependency information for isort from https://files.pythonhosted.org/packages/d1/b3/8def84f539e7d2289a02f0524b944b15d7c75dab7628bedf1c4f0992029c/isort-5.13.2-py3-none-any.whl.metadata
#   Downloading isort-5.13.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy in /home/aditya-kumar/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from sinergym) (2.0.1)
# Collecting opyplus (from sinergym)
#   Obtaining dependency information for opyplus from https://files.pythonhosted.org/packages/c4/1e/a0577eb81fa8fd835a1d906ee4df2a341f82aa81fcccdeefb916d89d75e8/opyplus-2.0.7-py3-none-any.whl.metadata
#   Downloading opyplus-2.0.7-py3-none-any.whl.metadata (4.3 kB)
# Collecting pandas (from sinergym)
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/fc/a5/4d82be566f069d7a9a702dcdf6f9106df0e0b042e738043c0cc7ddd7e3f6/pandas-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading pandas-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting pytype (from sinergym)
#   Obtaining dependency information for pytype from https://files.pythonhosted.org/packages/86/8a/03609dada7c8c63b138d761efad215a4af0b2d0776b408b5f3fad416c1fc/pytype-2024.4.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading pytype-2024.4.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting twine (from sinergym)
#   Obtaining dependency information for twine from https://files.pythonhosted.org/packages/5d/ec/00f9d5fd040ae29867355e559a94e9a8429225a0284a3f5f091a3878bfc0/twine-5.1.1-py3-none-any.whl.metadata
#   Downloading twine-5.1.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting xlsxwriter (from sinergym)
#   Obtaining dependency information for xlsxwriter from https://files.pythonhosted.org/packages/a7/ea/53d1fe468e63e092cf16e2c18d16f50c29851242f9dd12d6a66e0d7f0d02/XlsxWriter-3.2.0-py3-none-any.whl.metadata
#   Downloading XlsxWriter-3.2.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pipdeptree (from sinergym)
#   Obtaining dependency information for pipdeptree from https://files.pythonhosted.org/packages/78/e4/835070f206a050d606ab8fa707b02994e4d0d6f345c88857d8ed32353fb3/pipdeptree-2.23.1-py3-none-any.whl.metadata
#   Downloading pipdeptree-2.23.1-py3-none-any.whl.metadata (15 kB)
# Collecting pycodestyle>=2.12.0 (from autopep8->sinergym)
#   Obtaining dependency information for pycodestyle>=2.12.0 from https://files.pythonhosted.org/packages/3a/d8/a211b3f85e99a0daa2ddec96c949cac6824bd305b040571b82a03dd62636/pycodestyle-2.12.1-py2.py3-none-any.whl.metadata
#   Downloading pycodestyle-2.12.1-py2.py3-none-any.whl.metadata (4.5 kB)
# Collecting munch>=2.0.2 (from eppy->sinergym)
#   Obtaining dependency information for munch>=2.0.2 from https://files.pythonhosted.org/packages/56/b3/7c69b37f03260a061883bec0e7b05be7117c1b1c85f5212c72c8c2bc3c8c/munch-4.0.0-py2.py3-none-any.whl.metadata
#   Downloading munch-4.0.0-py2.py3-none-any.whl.metadata (5.9 kB)
# Collecting beautifulsoup4<=4.8.0 (from eppy->sinergym)
#   Obtaining dependency information for beautifulsoup4<=4.8.0 from https://files.pythonhosted.org/packages/1a/b7/34eec2fe5a49718944e215fde81288eec1fa04638aa3fb57c1c6cd0f98c3/beautifulsoup4-4.8.0-py3-none-any.whl.metadata
#   Downloading beautifulsoup4-4.8.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting tinynumpy>=1.2.1 (from eppy->sinergym)
#   Using cached tinynumpy-1.2.1-py3-none-any.whl
# Requirement already satisfied: six>=1.10.0 in /home/aditya-kumar/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from eppy->sinergym) (1.16.0)
# Requirement already satisfied: decorator>=4.0.10 in /home/aditya-kumar/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from eppy->sinergym) (5.1.1)
# Collecting lxml>=3.8.0 (from eppy->sinergym)
#   Obtaining dependency information for lxml>=3.8.0 from https://files.pythonhosted.org/packages/42/07/b29571a58a3a80681722ea8ed0ba569211d9bb8531ad49b5cacf6d409185/lxml-5.3.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata
#   Downloading lxml-5.3.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting future (from eppy->sinergym)
#   Obtaining dependency information for future from https://files.pythonhosted.org/packages/da/71/ae30dadffc90b9006d77af76b393cb9dfbfc9629f339fc1574a1c52e6806/future-1.0.0-py3-none-any.whl.metadata
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting pydot3k (from eppy->sinergym)
#   Using cached pydot3k-1.0.17-py3-none-any.whl
# Collecting pyparsing>=2.4.7 (from eppy->sinergym)
#   Obtaining dependency information for pyparsing>=2.4.7 from https://files.pythonhosted.org/packages/9d/ea/6d76df31432a0e6fdf81681a895f009a4bb47b3c39036db3e1b528191d52/pyparsing-3.1.2-py3-none-any.whl.metadata
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/aditya-kumar/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from gymnasium->sinergym) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/aditya-kumar/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from gymnasium->sinergym) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/aditya-kumar/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from gymnasium->sinergym) (0.0.4)
# Collecting unidecode<2.0,>=1.0.22 (from opyplus->sinergym)
#   Obtaining dependency information for unidecode<2.0,>=1.0.22 from https://files.pythonhosted.org/packages/84/b7/6ec57841fb67c98f52fc8e4a2d96df60059637cba077edc569a302a8ffc7/Unidecode-1.3.8-py3-none-any.whl.metadata
#   Downloading Unidecode-1.3.8-py3-none-any.whl.metadata (13 kB)
# Collecting python-slugify<6.0,>=3.0.2 (from opyplus->sinergym)
#   Obtaining dependency information for python-slugify<6.0,>=3.0.2 from https://files.pythonhosted.org/packages/7e/e2/0c8be1e3b237d11f10963c7cef82e4d98d70ca6e176f3922dddf7bfc7026/python_slugify-5.0.2-py2.py3-none-any.whl.metadata
#   Downloading python_slugify-5.0.2-py2.py3-none-any.whl.metadata (995 bytes)
# Collecting charset-normalizer<4.0,>=3.2.0 (from opyplus->sinergym)
#   Obtaining dependency information for charset-normalizer<4.0,>=3.2.0 from https://files.pythonhosted.org/packages/40/26/f35951c45070edc957ba40a5b1db3cf60a9dbb1b350c2d5bef03e01e61de/charset_normalizer-3.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading charset_normalizer-3.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/aditya-kumar/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from pandas->sinergym) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->sinergym)
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/9c/3d/a121f284241f08268b21359bd425f7d4825cffc5ac5cd0e1b3d82ffd2b10/pytz-2024.1-py2.py3-none-any.whl.metadata
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->sinergym)
#   Obtaining dependency information for tzdata>=2022.7 from https://files.pythonhosted.org/packages/65/58/f9c9e6be752e9fcb8b6a0ee9fb87e6e7a1f6bcab2cdc73f02bb7ba91ada0/tzdata-2024.1-py2.py3-none-any.whl.metadata
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: packaging>=23.1 in /home/aditya-kumar/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from pipdeptree->sinergym) (24.1)
# Requirement already satisfied: pip>=23.1.2 in /home/aditya-kumar/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from pipdeptree->sinergym) (23.2.1)
# Collecting attrs>=21.4.0 (from pytype->sinergym)
#   Obtaining dependency information for attrs>=21.4.0 from https://files.pythonhosted.org/packages/6a/21/5b6702a7f963e95456c0de2d495f67bf5fd62840ac655dc451586d23d39a/attrs-24.2.0-py3-none-any.whl.metadata
#   Downloading attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting importlab>=0.8 (from pytype->sinergym)
#   Obtaining dependency information for importlab>=0.8 from https://files.pythonhosted.org/packages/da/1e/cc7360b4259f283b1a2de153335ce15ac9e710d66145aa471cffefe4b394/importlab-0.8.1-py2.py3-none-any.whl.metadata
#   Downloading importlab-0.8.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting immutabledict>=4.1.0 (from pytype->sinergym)
#   Obtaining dependency information for immutabledict>=4.1.0 from https://files.pythonhosted.org/packages/e2/13/3cf4ac5b3403f3456e645c4533883ef67b1bb0c72e56b79c707715f57a74/immutabledict-4.2.0-py3-none-any.whl.metadata
#   Downloading immutabledict-4.2.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting jinja2>=3.1.2 (from pytype->sinergym)
#   Obtaining dependency information for jinja2>=3.1.2 from https://files.pythonhosted.org/packages/31/80/3a54838c3fb461f6fec263ebf3a3a41771bd05190238de3486aae8540c36/jinja2-3.1.4-py3-none-any.whl.metadata
#   Downloading jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting libcst>=1.0.1 (from pytype->sinergym)
#   Obtaining dependency information for libcst>=1.0.1 from https://files.pythonhosted.org/packages/50/a1/2093f74a3f8936fcdaac01f86d1c5fa8f586202afa466a92332b9a461b14/libcst-1.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading libcst-1.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (17 kB)
# Collecting msgspec>=0.18.6 (from pytype->sinergym)
#   Obtaining dependency information for msgspec>=0.18.6 from https://files.pythonhosted.org/packages/6a/73/1b2f991dc26899d2f999c938cbc82c858b3cb7e3ccaad317b32760dbe1da/msgspec-0.18.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading msgspec-0.18.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Collecting networkx<3.2 (from pytype->sinergym)
#   Obtaining dependency information for networkx<3.2 from https://files.pythonhosted.org/packages/a8/05/9d4f9b78ead6b2661d6e8ea772e111fc4a9fbd866ad0c81906c11206b55e/networkx-3.1-py3-none-any.whl.metadata
#   Downloading networkx-3.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting ninja>=1.10.0.post2 (from pytype->sinergym)
#   Obtaining dependency information for ninja>=1.10.0.post2 from https://files.pythonhosted.org/packages/6d/92/8d7aebd4430ab5ff65df2bfee6d5745f95c004284db2d8ca76dcbfd9de47/ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl.metadata
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl.metadata (5.3 kB)
# Collecting pycnite>=2023.10.11 (from pytype->sinergym)
#   Obtaining dependency information for pycnite>=2023.10.11 from https://files.pythonhosted.org/packages/20/af/7ba371f966657f6e7b1c9876cae7e9f1c5d3635c3df1329636b99e615494/pycnite-2024.7.31-py3-none-any.whl.metadata
#   Downloading pycnite-2024.7.31-py3-none-any.whl.metadata (1.3 kB)
# Collecting pydot>=1.4.2 (from pytype->sinergym)
#   Obtaining dependency information for pydot>=1.4.2 from https://files.pythonhosted.org/packages/9a/fd/df3932340498a8f38c6107c95b0eb1d9ac406c5ea1307c8f43408977378e/pydot-3.0.1-py3-none-any.whl.metadata
#   Downloading pydot-3.0.1-py3-none-any.whl.metadata (9.9 kB)
# Collecting tabulate>=0.8.10 (from pytype->sinergym)
#   Obtaining dependency information for tabulate>=0.8.10 from https://files.pythonhosted.org/packages/40/44/4a5f08c96eb108af5cb50b41f76142f0afa346dfa99d5296fe7202a11854/tabulate-0.9.0-py3-none-any.whl.metadata
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting toml>=0.10.2 (from pytype->sinergym)
#   Obtaining dependency information for toml>=0.10.2 from https://files.pythonhosted.org/packages/44/6f/7120676b6d73228c96e17f1f794d8ab046fc910d781c8d151120c3f1569e/toml-0.10.2-py2.py3-none-any.whl.metadata
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Collecting pkginfo>=1.8.1 (from twine->sinergym)
#   Obtaining dependency information for pkginfo>=1.8.1 from https://files.pythonhosted.org/packages/c0/38/d617739840a2f576e400f03fea0a75703f93cc274002635b4b998bbb9de4/pkginfo-1.11.1-py3-none-any.whl.metadata
#   Downloading pkginfo-1.11.1-py3-none-any.whl.metadata (11 kB)
# Collecting readme-renderer>=35.0 (from twine->sinergym)
#   Obtaining dependency information for readme-renderer>=35.0 from https://files.pythonhosted.org/packages/e1/67/921ec3024056483db83953ae8e48079ad62b92db7880013ca77632921dd0/readme_renderer-44.0-py3-none-any.whl.metadata
#   Downloading readme_renderer-44.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting requests>=2.20 (from twine->sinergym)
#   Obtaining dependency information for requests>=2.20 from https://files.pythonhosted.org/packages/f9/9b/335f9764261e915ed497fcdeb11df5dfd6f7bf257d4a6a2a686d80da4d54/requests-2.32.3-py3-none-any.whl.metadata
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting requests-toolbelt!=0.9.0,>=0.8.0 (from twine->sinergym)
#   Obtaining dependency information for requests-toolbelt!=0.9.0,>=0.8.0 from https://files.pythonhosted.org/packages/3f/51/d4db610ef29373b879047326cbf6fa98b6c1969d6f6dc423279de2b1be2c/requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting urllib3>=1.26.0 (from twine->sinergym)
#   Obtaining dependency information for urllib3>=1.26.0 from https://files.pythonhosted.org/packages/ca/1c/89ffc63a9605b583d5df2be791a27bc1a42b7c32bab68d3c8f2f73a98cd4/urllib3-2.2.2-py3-none-any.whl.metadata
#   Downloading urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting importlib-metadata>=3.6 (from twine->sinergym)
#   Obtaining dependency information for importlib-metadata>=3.6 from https://files.pythonhosted.org/packages/82/47/bb25ec04985d0693da478797c3d8c1092b140f3a53ccb984fbbd38affa5b/importlib_metadata-8.2.0-py3-none-any.whl.metadata
#   Downloading importlib_metadata-8.2.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting keyring>=15.1 (from twine->sinergym)
#   Obtaining dependency information for keyring>=15.1 from https://files.pythonhosted.org/packages/63/42/ea8c9726e5ee5ff0731978aaf7cd5fa16674cf549c46279b279d7167c2b4/keyring-25.3.0-py3-none-any.whl.metadata
#   Downloading keyring-25.3.0-py3-none-any.whl.metadata (20 kB)
# Collecting rfc3986>=1.4.0 (from twine->sinergym)
#   Obtaining dependency information for rfc3986>=1.4.0 from https://files.pythonhosted.org/packages/ff/9a/9afaade874b2fa6c752c36f1548f718b5b83af81ed9b76628329dab81c1b/rfc3986-2.0.0-py2.py3-none-any.whl.metadata
#   Downloading rfc3986-2.0.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Collecting rich>=12.0.0 (from twine->sinergym)
#   Obtaining dependency information for rich>=12.0.0 from https://files.pythonhosted.org/packages/87/67/a37f6214d0e9fe57f6ae54b2956d550ca8365857f42a1ce0392bb21d9410/rich-13.7.1-py3-none-any.whl.metadata
#   Downloading rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting pkginfo>=1.8.1 (from twine->sinergym)
#   Obtaining dependency information for pkginfo>=1.8.1 from https://files.pythonhosted.org/packages/56/09/054aea9b7534a15ad38a363a2bd974c20646ab1582a387a95b8df1bfea1c/pkginfo-1.10.0-py3-none-any.whl.metadata
#   Downloading pkginfo-1.10.0-py3-none-any.whl.metadata (11 kB)
# Collecting soupsieve>=1.2 (from beautifulsoup4<=4.8.0->eppy->sinergym)
#   Obtaining dependency information for soupsieve>=1.2 from https://files.pythonhosted.org/packages/4c/f3/038b302fdfbe3be7da016777069f26ceefe11a681055ea1f7817546508e3/soupsieve-2.5-py3-none-any.whl.metadata
#   Downloading soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting zipp>=0.5 (from importlib-metadata>=3.6->twine->sinergym)
#   Obtaining dependency information for zipp>=0.5 from https://files.pythonhosted.org/packages/da/cc/b9958af9f9c86b51f846d8487440af495ecf19b16e426fce1ed0b0796175/zipp-3.20.0-py3-none-any.whl.metadata
#   Downloading zipp-3.20.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2>=3.1.2->pytype->sinergym)
#   Obtaining dependency information for MarkupSafe>=2.0 from https://files.pythonhosted.org/packages/97/18/c30da5e7a0e7f4603abfc6780574131221d9148f323752c2755d48abad30/MarkupSafe-2.1.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading MarkupSafe-2.1.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting jaraco.classes (from keyring>=15.1->twine->sinergym)
#   Obtaining dependency information for jaraco.classes from https://files.pythonhosted.org/packages/7f/66/b15ce62552d84bbfcec9a4873ab79d993a1dd4edb922cbfccae192bd5b5f/jaraco.classes-3.4.0-py3-none-any.whl.metadata
#   Downloading jaraco.classes-3.4.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting jaraco.functools (from keyring>=15.1->twine->sinergym)
#   Obtaining dependency information for jaraco.functools from https://files.pythonhosted.org/packages/b1/54/7623e24ffc63730c3a619101361b08860c6b7c7cfc1aef6edb66d80ed708/jaraco.functools-4.0.2-py3-none-any.whl.metadata
#   Downloading jaraco.functools-4.0.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting jaraco.context (from keyring>=15.1->twine->sinergym)
#   Obtaining dependency information for jaraco.context from https://files.pythonhosted.org/packages/d2/40/11b7bc1898cf1dcb87ccbe09b39f5088634ac78bb25f3383ff541c2b40aa/jaraco.context-5.3.0-py3-none-any.whl.metadata
#   Downloading jaraco.context-5.3.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting SecretStorage>=3.2 (from keyring>=15.1->twine->sinergym)
#   Obtaining dependency information for SecretStorage>=3.2 from https://files.pythonhosted.org/packages/54/24/b4293291fa1dd830f353d2cb163295742fa87f179fcc8a20a306a81978b7/SecretStorage-3.3.3-py3-none-any.whl.metadata
#   Downloading SecretStorage-3.3.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting jeepney>=0.4.2 (from keyring>=15.1->twine->sinergym)
#   Obtaining dependency information for jeepney>=0.4.2 from https://files.pythonhosted.org/packages/ae/72/2a1e2290f1ab1e06f71f3d0f1646c9e4634e70e1d37491535e19266e8dc9/jeepney-0.8.0-py3-none-any.whl.metadata
#   Downloading jeepney-0.8.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting pyyaml>=5.2 (from libcst>=1.0.1->pytype->sinergym)
#   Obtaining dependency information for pyyaml>=5.2 from https://files.pythonhosted.org/packages/75/e4/2c27590dfc9992f73aabbeb9241ae20220bd9452df27483b6e56d3975cc5/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting text-unidecode>=1.3 (from python-slugify<6.0,>=3.0.2->opyplus->sinergym)
#   Obtaining dependency information for text-unidecode>=1.3 from https://files.pythonhosted.org/packages/a6/a5/c0b6468d3824fe3fde30dbb5e1f687b291608f9473681bbf7dabbf5a87d7/text_unidecode-1.3-py2.py3-none-any.whl.metadata
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting nh3>=0.2.14 (from readme-renderer>=35.0->twine->sinergym)
#   Obtaining dependency information for nh3>=0.2.14 from https://files.pythonhosted.org/packages/1b/63/6ab90d0e5225ab9780f6c9fb52254fa36b52bb7c188df9201d05b647e5e1/nh3-0.2.18-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading nh3-0.2.18-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting docutils>=0.21.2 (from readme-renderer>=35.0->twine->sinergym)
#   Obtaining dependency information for docutils>=0.21.2 from https://files.pythonhosted.org/packages/8f/d7/9322c609343d929e75e7e5e6255e614fcc67572cfd083959cdef3b7aad79/docutils-0.21.2-py3-none-any.whl.metadata
#   Downloading docutils-0.21.2-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: Pygments>=2.5.1 in /home/aditya-kumar/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from readme-renderer>=35.0->twine->sinergym) (2.18.0)
# Collecting idna<4,>=2.5 (from requests>=2.20->twine->sinergym)
#   Obtaining dependency information for idna<4,>=2.5 from https://files.pythonhosted.org/packages/e5/3e/741d8c82801c347547f8a2a06aa57dbb1992be9e948df2ea0eda2c8b79e8/idna-3.7-py3-none-any.whl.metadata
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.20->twine->sinergym)
#   Obtaining dependency information for certifi>=2017.4.17 from https://files.pythonhosted.org/packages/1c/d5/c84e1a17bf61d4df64ca866a1c9a913874b4e9bdc131ec689a0ad013fb36/certifi-2024.7.4-py3-none-any.whl.metadata
#   Downloading certifi-2024.7.4-py3-none-any.whl.metadata (2.2 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=12.0.0->twine->sinergym)
#   Obtaining dependency information for markdown-it-py>=2.2.0 from https://files.pythonhosted.org/packages/42/d7/1ec15b46af6af88f19b8e5ffea08fa375d433c998b8a7639e76935c14f1f/markdown_it_py-3.0.0-py3-none-any.whl.metadata
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: setuptools in /home/aditya-kumar/.pyenv/versions/3.11.5/lib/python3.11/site-packages (from pydot3k->eppy->sinergym) (65.5.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=12.0.0->twine->sinergym)
#   Obtaining dependency information for mdurl~=0.1 from https://files.pythonhosted.org/packages/b3/38/89ba8ad64ae25be8de66a6d463314cf1eb366222074cfda9ee839c56a4b4/mdurl-0.1.2-py3-none-any.whl.metadata
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting cryptography>=2.0 (from SecretStorage>=3.2->keyring>=15.1->twine->sinergym)
#   Obtaining dependency information for cryptography>=2.0 from https://files.pythonhosted.org/packages/0f/6c/b42660b3075ff543065b2c1c5a3d9bedaadcff8ebce2ee981be2babc2934/cryptography-43.0.0-cp39-abi3-manylinux_2_28_x86_64.whl.metadata
#   Downloading cryptography-43.0.0-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Collecting more-itertools (from jaraco.classes->keyring>=15.1->twine->sinergym)
#   Obtaining dependency information for more-itertools from https://files.pythonhosted.org/packages/d8/0b/6a51175e1395774449fca317fb8861379b7a2d59be411b8cce3d19d6ce78/more_itertools-10.4.0-py3-none-any.whl.metadata
#   Downloading more_itertools-10.4.0-py3-none-any.whl.metadata (36 kB)
# Collecting backports.tarfile (from jaraco.context->keyring>=15.1->twine->sinergym)
#   Obtaining dependency information for backports.tarfile from https://files.pythonhosted.org/packages/b9/fa/123043af240e49752f1c4bd24da5053b6bd00cad78c2be53c0d1e8b975bc/backports.tarfile-1.2.0-py3-none-any.whl.metadata
#   Downloading backports.tarfile-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting cffi>=1.12 (from cryptography>=2.0->SecretStorage>=3.2->keyring>=15.1->twine->sinergym)
#   Obtaining dependency information for cffi>=1.12 from https://files.pythonhosted.org/packages/f3/b9/f163bb3fa4fbc636ee1f2a6a4598c096cdef279823ddfaa5734e556dd206/cffi-1.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading cffi-1.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting pycparser (from cffi>=1.12->cryptography>=2.0->SecretStorage>=3.2->keyring>=15.1->twine->sinergym)
#   Obtaining dependency information for pycparser from https://files.pythonhosted.org/packages/13/a3/a812df4e2dd5696d1f351d58b8fe16a405b234ad2886a0dab9183fb78109/pycparser-2.22-py3-none-any.whl.metadata
#   Downloading pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Downloading autopep8-2.3.1-py2.py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 7.9 MB/s eta 0:00:00
# Downloading eppy-0.5.63-py2.py3-none-any.whl (869 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 869.7/869.7 kB 46.4 MB/s eta 0:00:00
# Downloading isort-5.13.2-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.3/92.3 kB 16.8 MB/s eta 0:00:00
# Downloading opyplus-2.0.7-py3-none-any.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 22.9 MB/s eta 0:00:0000:0100:01
# Downloading pandas-2.2.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 22.7 MB/s eta 0:00:0000:0100:01
# Downloading pipdeptree-2.23.1-py3-none-any.whl (32 kB)
# Downloading pytype-2024.4.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 24.5 MB/s eta 0:00:0000:0100:01
# Downloading twine-5.1.1-py3-none-any.whl (38 kB)
# Downloading XlsxWriter-3.2.0-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.9/159.9 kB 13.1 MB/s eta 0:00:00
# Downloading attrs-24.2.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 kB 6.1 MB/s eta 0:00:00
# Downloading beautifulsoup4-4.8.0-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 kB 10.6 MB/s eta 0:00:00
# Downloading charset_normalizer-3.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.3/140.3 kB 10.8 MB/s eta 0:00:00
# Downloading immutabledict-4.2.0-py3-none-any.whl (4.7 kB)
# Downloading importlab-0.8.1-py2.py3-none-any.whl (21 kB)
# Downloading importlib_metadata-8.2.0-py3-none-any.whl (25 kB)
# Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.3/133.3 kB 10.3 MB/s eta 0:00:00
# Downloading keyring-25.3.0-py3-none-any.whl (38 kB)
# Downloading libcst-1.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 44.2 MB/s eta 0:00:00a 0:00:01
# Downloading lxml-5.3.0-cp311-cp311-manylinux_2_28_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 32.6 MB/s eta 0:00:0000:0100:01
# Downloading msgspec-0.18.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 kB 20.4 MB/s eta 0:00:00
# Downloading munch-4.0.0-py2.py3-none-any.whl (9.9 kB)
# Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 25.2 MB/s eta 0:00:0000:0100:01
# Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 22.3 MB/s eta 0:00:00
# Downloading pkginfo-1.10.0-py3-none-any.whl (30 kB)
# Downloading pycnite-2024.7.31-py3-none-any.whl (22 kB)
# Downloading pycodestyle-2.12.1-py2.py3-none-any.whl (31 kB)
# Downloading pydot-3.0.1-py3-none-any.whl (22 kB)
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 11.2 MB/s eta 0:00:00
# Downloading python_slugify-5.0.2-py2.py3-none-any.whl (6.7 kB)
# Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.5/505.5 kB 24.4 MB/s eta 0:00:00
# Downloading readme_renderer-44.0-py3-none-any.whl (13 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 5.5 MB/s eta 0:00:00
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.8 MB/s eta 0:00:00
# Downloading rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 kB 20.7 MB/s eta 0:00:00
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 25.2 MB/s eta 0:00:00
# Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 11.3 MB/s eta 0:00:00
# Downloading urllib3-2.2.2-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.4/121.4 kB 11.8 MB/s eta 0:00:00
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.3/491.3 kB 23.5 MB/s eta 0:00:00
# Downloading certifi-2024.7.4-py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.0/163.0 kB 23.2 MB/s eta 0:00:00
# Downloading docutils-0.21.2-py3-none-any.whl (587 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.4/587.4 kB 42.7 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 10.7 MB/s eta 0:00:00
# Downloading jeepney-0.8.0-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 8.2 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 18.7 MB/s eta 0:00:00
# Downloading MarkupSafe-2.1.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28 kB)
# Downloading nh3-0.2.18-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (769 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 769.2/769.2 kB 40.2 MB/s eta 0:00:00
# Downloading PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (762 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 31.2 MB/s eta 0:00:00
# Downloading SecretStorage-3.3.3-py3-none-any.whl (15 kB)
# Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 6.5 MB/s eta 0:00:00
# Downloading zipp-3.20.0-py3-none-any.whl (9.4 kB)
# Downloading jaraco.classes-3.4.0-py3-none-any.whl (6.8 kB)
# Downloading jaraco.context-5.3.0-py3-none-any.whl (6.5 kB)
# Downloading jaraco.functools-4.0.2-py3-none-any.whl (9.9 kB)
# Downloading cryptography-43.0.0-cp39-abi3-manylinux_2_28_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 33.9 MB/s eta 0:00:0000:0100:01
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading backports.tarfile-1.2.0-py3-none-any.whl (30 kB)
# Downloading more_itertools-10.4.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 14.4 MB/s eta 0:00:00
# Downloading cffi-1.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (466 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 466.9/466.9 kB 44.8 MB/s eta 0:00:00
# Downloading pycparser-2.22-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.6/117.6 kB 21.8 MB/s eta 0:00:00
# Building wheels for collected packages: sinergym
#   Building wheel for sinergym (pyproject.toml) ... done
#   Created wheel for sinergym: filename=sinergym-3.4.0-py3-none-any.whl size=3376658 sha256=c0e5f98f5bf832c6b5f7364cd17b22b408469ce054d329f6681acb6e49ff20c5
#   Stored in directory: /home/aditya-kumar/.cache/pip/wheels/80/c9/4f/5537f3204fce2137bed6a4ca7110e1c14ac8a95efa8ed55702
# Successfully built sinergym
# Installing collected packages: tinynumpy, text-unidecode, pytz, ninja, nh3, zipp, xlsxwriter, urllib3, unidecode, tzdata, toml, tabulate, soupsieve, rfc3986, pyyaml, python-slugify, pyparsing, pycparser, pycodestyle, pycnite, pkginfo, pipdeptree, networkx, munch, msgspec, more-itertools, mdurl, MarkupSafe, lxml, jeepney, isort, immutabledict, idna, future, docutils, charset-normalizer, certifi, backports.tarfile, attrs, requests, readme-renderer, pydot3k, pydot, pandas, markdown-it-py, libcst, jinja2, jaraco.functools, jaraco.context, jaraco.classes, importlib-metadata, importlab, cffi, beautifulsoup4, autopep8, rich, requests-toolbelt, pytype, opyplus, eppy, cryptography, SecretStorage, keyring, twine, sinergym
# Successfully installed MarkupSafe-2.1.5 SecretStorage-3.3.3 attrs-24.2.0 autopep8-2.3.1 backports.tarfile-1.2.0 beautifulsoup4-4.8.0 certifi-2024.7.4 cffi-1.17.0 charset-normalizer-3.3.2 cryptography-43.0.0 docutils-0.21.2 eppy-0.5.63 future-1.0.0 idna-3.7 immutabledict-4.2.0 importlab-0.8.1 importlib-metadata-8.2.0 isort-5.13.2 jaraco.classes-3.4.0 jaraco.context-5.3.0 jaraco.functools-4.0.2 jeepney-0.8.0 jinja2-3.1.4 keyring-25.3.0 libcst-1.4.0 lxml-5.3.0 markdown-it-py-3.0.0 mdurl-0.1.2 more-itertools-10.4.0 msgspec-0.18.6 munch-4.0.0 networkx-3.1 nh3-0.2.18 ninja-1.11.1.1 opyplus-2.0.7 pandas-2.2.2 pipdeptree-2.23.1 pkginfo-1.10.0 pycnite-2024.7.31 pycodestyle-2.12.1 pycparser-2.22 pydot-3.0.1 pydot3k-1.0.17 pyparsing-3.1.2 python-slugify-5.0.2 pytype-2024.4.11 pytz-2024.1 pyyaml-6.0.2 readme-renderer-44.0 requests-2.32.3 requests-toolbelt-1.0.0 rfc3986-2.0.0 rich-13.7.1 sinergym-3.4.0 soupsieve-2.5 tabulate-0.9.0 text-unidecode-1.3 tinynumpy-1.2.1 toml-0.10.2 twine-5.1.1 tzdata-2024.1 unidecode-1.3.8 urllib3-2.2.2 xlsxwriter-3.2.0 zipp-3.20.0
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import gymnasium as gym
import sinergym

all_envs = gym.envs.registry.keys()

sinergym_envs = [env for env in all_envs if env.startswith('Eplus-')]
print("Available Sinergym Environments:")
for env in sinergym_envs:
    print(f"- {env}")

print(f"\nTotal Sinergym environments available: {len(sinergym_envs)}")
# Out:
# Available Sinergym Environments:
# - Eplus-demo-v1
# - Eplus-warehouse-hot-continuous-v1
# - Eplus-warehouse-hot-discrete-v1
# - Eplus-warehouse-hot-continuous-stochastic-v1
# - Eplus-warehouse-hot-discrete-stochastic-v1
# - Eplus-warehouse-mixed-continuous-v1
# - Eplus-warehouse-mixed-discrete-v1
# - Eplus-warehouse-mixed-continuous-stochastic-v1
# - Eplus-warehouse-mixed-discrete-stochastic-v1
# - Eplus-warehouse-cool-continuous-v1
# - Eplus-warehouse-cool-discrete-v1
# - Eplus-warehouse-cool-continuous-stochastic-v1
# - Eplus-warehouse-cool-discrete-stochastic-v1
# - Eplus-officegrid-hot-continuous-v1
# - Eplus-officegrid-hot-discrete-v1
# - Eplus-officegrid-hot-continuous-stochastic-v1
# - Eplus-officegrid-hot-discrete-stochastic-v1
# - Eplus-officegrid-mixed-continuous-v1
# - Eplus-officegrid-mixed-discrete-v1
# - Eplus-officegrid-mixed-continuous-stochastic-v1
# - Eplus-officegrid-mixed-discrete-stochastic-v1
# - Eplus-officegrid-cool-continuous-v1
# - Eplus-officegrid-cool-discrete-v1
# - Eplus-officegrid-cool-continuous-stochastic-v1
# - Eplus-officegrid-cool-discrete-stochastic-v1
# - Eplus-datacenter-hot-continuous-v1
# - Eplus-datacenter-hot-discrete-v1
# - Eplus-datacenter-hot-continuous-stochastic-v1
# - Eplus-datacenter-hot-discrete-stochastic-v1
# - Eplus-datacenter-mixed-continuous-v1
# - Eplus-datacenter-mixed-discrete-v1
# - Eplus-datacenter-mixed-continuous-stochastic-v1
# - Eplus-datacenter-mixed-discrete-stochastic-v1
# - Eplus-datacenter-cool-continuous-v1
# - Eplus-datacenter-cool-discrete-v1
# - Eplus-datacenter-cool-continuous-stochastic-v1
# - Eplus-datacenter-cool-discrete-stochastic-v1
# - Eplus-shop-hot-continuous-v1
# - Eplus-shop-hot-discrete-v1
# - Eplus-shop-hot-continuous-stochastic-v1
# - Eplus-shop-hot-discrete-stochastic-v1
# - Eplus-shop-mixed-continuous-v1
# - Eplus-shop-mixed-discrete-v1
# - Eplus-shop-mixed-continuous-stochastic-v1
# - Eplus-shop-mixed-discrete-stochastic-v1
# - Eplus-shop-cool-continuous-v1
# - Eplus-shop-cool-discrete-v1
# - Eplus-shop-cool-continuous-stochastic-v1
# - Eplus-shop-cool-discrete-stochastic-v1
# - Eplus-office-hot-continuous-v1
# - Eplus-office-hot-discrete-v1
# - Eplus-office-hot-continuous-stochastic-v1
# - Eplus-office-hot-discrete-stochastic-v1
# - Eplus-office-mixed-continuous-v1
# - Eplus-office-mixed-discrete-v1
# - Eplus-office-mixed-continuous-stochastic-v1
# - Eplus-office-mixed-discrete-stochastic-v1
# - Eplus-office-cool-continuous-v1
# - Eplus-office-cool-discrete-v1
# - Eplus-office-cool-continuous-stochastic-v1
# - Eplus-office-cool-discrete-stochastic-v1
# - Eplus-smalldatacenter-hot-continuous-v1
# - Eplus-smalldatacenter-hot-continuous-stochastic-v1
# - Eplus-smalldatacenter-mixed-continuous-v1
# - Eplus-smalldatacenter-mixed-continuous-stochastic-v1
# - Eplus-smalldatacenter-cool-continuous-v1
# - Eplus-smalldatacenter-cool-continuous-stochastic-v1
# - Eplus-5zone-hot-continuous-v1
# - Eplus-5zone-hot-discrete-v1
# - Eplus-5zone-hot-continuous-stochastic-v1
# - Eplus-5zone-hot-discrete-stochastic-v1
# - Eplus-5zone-mixed-continuous-v1
# - Eplus-5zone-mixed-discrete-v1
# - Eplus-5zone-mixed-continuous-stochastic-v1
# - Eplus-5zone-mixed-discrete-stochastic-v1
# - Eplus-5zone-cool-continuous-v1
# - Eplus-5zone-cool-discrete-v1
# - Eplus-5zone-cool-continuous-stochastic-v1
# - Eplus-5zone-cool-discrete-stochastic-v1
# - Eplus-radiant-hot-discrete-v1
# - Eplus-radiant-hot-discrete-stochastic-v1
# - Eplus-radiant-mixed-discrete-v1
# - Eplus-radiant-mixed-discrete-stochastic-v1
# - Eplus-radiant-cool-discrete-v1
# - Eplus-radiant-cool-discrete-stochastic-v1
# - Eplus-radiant-stockholm-discrete-v1
# - Eplus-radiant-stockholm-discrete-stochastic-v1
#
# Total Sinergym environments available: 87

# %%
import gymnasium as gym
import numpy as np
import os

os.environ['EPLUS_PATH'] = '/usr/local/EnergyPlus-23-1-0' 
# Add pyenergyplus path to PYTHONPATH (Ubuntu)
pyenergyplus_path = '/usr/local/EnergyPlus-23-1-0/pyenergyplus'
os.environ['PYTHONPATH'] = os.environ.get('PYTHONPATH', '') + ':' + pyenergyplus_path

import sinergym
env = gym.make('Eplus-demo-v1')
# Out:
# #==============================================================================================#
# [ENVIRONMENT] (INFO) : Creating Gymnasium environment... [demo-v1]
# #==============================================================================================#
# [MODELING] (INFO) : Experiment working directory created [/home/aditya-kumar/Desktop/UROP/hitl_hvac/sinergym/examples/Eplus-env-demo-v1-res1]
# [MODELING] (INFO) : Model Config is correct.
# [MODELING] (INFO) : Updated building model with whole Output:Variable available names
# [MODELING] (INFO) : Updated building model with whole Output:Meter available names
# [MODELING] (INFO) : Extra config: runperiod updated to {'apply_weekend_holiday_rule': 'No', 'begin_day_of_month': 1, 'begin_month': 1, 'begin_year': 1991, 'day_of_week_for_start_day': 'Monday', 'end_day_of_month': 1, 'end_month': 3, 'end_year': 1991, 'use_weather_file_daylight_saving_period': 'Yes', 'use_weather_file_holidays_and_special_days': 'Yes', 'use_weather_file_rain_indicators': 'Yes', 'use_weather_file_snow_indicators': 'Yes'}
# [MODELING] (INFO) : Updated episode length (seconds): 5184000.0
# [MODELING] (INFO) : Updated timestep size (seconds): 3600.0
# [MODELING] (INFO) : Updated timesteps per episode: 1440
# [MODELING] (INFO) : runperiod established: {'start_day': 1, 'start_month': 1, 'start_year': 1991, 'end_day': 1, 'end_month': 3, 'end_year': 1991, 'start_weekday': 0, 'n_steps_per_hour': 1}
# [MODELING] (INFO) : Episode length (seconds): 5184000.0
# [MODELING] (INFO) : timestep size (seconds): 3600.0
# [MODELING] (INFO) : timesteps per episode: 1440
# [REWARD] (INFO) : Reward function initialized.
# [ENVIRONMENT] (INFO) : Environment demo-v1 created successfully.
# /home/aditya-kumar/.pyenv/versions/3.11.5/lib/python3.11/site-packages/opyplus/weather_data/weather_data.py:531: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[k].fillna(value=np.nan, inplace=True)
# /home/aditya-kumar/.pyenv/versions/3.11.5/lib/python3.11/site-packages/opyplus/weather_data/weather_data.py:533: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[k].replace(
# /home/aditya-kumar/.pyenv/versions/3.11.5/lib/python3.11/site-packages/opyplus/weather_data/weather_data.py:522: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[k].fillna(value="", inplace=True)
# /home/aditya-kumar/.pyenv/versions/3.11.5/lib/python3.11/site-packages/opyplus/weather_data/weather_data.py:524: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[k].replace(

# %% [markdown]
# At first glance, Sinergym might seem to be only imported and not used. However, importing Sinergym inherently defines all its [Environments](https://ugr-sail.github.io/sinergym/compilation/html/pages/environments.html) for use. In this instance, `Eplus-demo-v1` is readily available with all its features.
#
# With this straightforward setup, we're prepared to iterate over the episodes. For this basic example, we'll consider just one episode. Essentially, the required code would look something like this:

# %%
for i in range(1):
    obs, info = env.reset()
    rewards = []
    truncated = terminated = False
    current_month = 0
    print('action space', env.action_space)
    while not (terminated or truncated):
        a = env.action_space.sample()
        obs, reward, terminated, truncated, info = env.step(a)
        rewards.append(reward)
        if info['month'] != current_month:  # display results every month
            current_month = info['month']
            print('Reward: ', sum(rewards), info)
# Out:
# #----------------------------------------------------------------------------------------------#
# [ENVIRONMENT] (INFO) : Starting a new episode... [demo-v1] [Episode 1]
# #----------------------------------------------------------------------------------------------#
# [MODELING] (INFO) : Episode directory created [/home/aditya-kumar/Desktop/UROP/hitl_hvac/sinergym/examples/Eplus-env-demo-v1-res1/Eplus-env-sub_run1]
# [MODELING] (INFO) : Weather file USA_PA_Pittsburgh-Allegheny.County.AP.725205_TMY3.epw used.
# [MODELING] (INFO) : Adapting weather to building model. [USA_PA_Pittsburgh-Allegheny.County.AP.725205_TMY3.epw]
# /home/aditya-kumar/.pyenv/versions/3.11.5/lib/python3.11/site-packages/opyplus/weather_data/weather_data.py:531: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[k].fillna(value=np.nan, inplace=True)
# /home/aditya-kumar/.pyenv/versions/3.11.5/lib/python3.11/site-packages/opyplus/weather_data/weather_data.py:533: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[k].replace(
# /home/aditya-kumar/.pyenv/versions/3.11.5/lib/python3.11/site-packages/opyplus/weather_data/weather_data.py:522: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[k].fillna(value="", inplace=True)
# /home/aditya-kumar/.pyenv/versions/3.11.5/lib/python3.11/site-packages/opyplus/weather_data/weather_data.py:524: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[k].replace(
# /home/aditya-kumar/.pyenv/versions/3.11.5/lib/python3.11/site-packages/opyplus/weather_data/weather_data.py:486: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace(
# [ENVIRONMENT] (INFO) : Saving episode output path... [/home/aditya-kumar/Desktop/UROP/hitl_hvac/sinergym/examples/Eplus-env-demo-v1-res1/Eplus-env-sub_run1/output]
# [SIMULATOR] (INFO) : Running EnergyPlus with args: ['-w', '/home/aditya-kumar/Desktop/UROP/hitl_hvac/sinergym/examples/Eplus-env-demo-v1-res1/Eplus-env-sub_run1/USA_PA_Pittsburgh-Allegheny.County.AP.725205_TMY3.epw', '-d', '/home/aditya-kumar/Desktop/UROP/hitl_hvac/sinergym/examples/Eplus-env-demo-v1-res1/Eplus-env-sub_run1/output', '/home/aditya-kumar/Desktop/UROP/hitl_hvac/sinergym/examples/Eplus-env-demo-v1-res1/Eplus-env-sub_run1/5ZoneAutoDXVAV.epJSON']
# [ENVIRONMENT] (INFO) : Episode 1 started.
# [SIMULATOR] (INFO) : handlers initialized.
# [SIMULATOR] (INFO) : handlers are ready.
# [SIMULATOR] (INFO) : System is ready.
# action space Box([15.  22.5], [22.5 30. ], (2,), float32)
# Reward:  -43.96143518328036 {'time_elapsed(hours)': 2.5, 'month': 1, 'day': 1, 'hour': 1, 'is_raining': False, 'action': array([20.485714, 26.822336], dtype=float32), 'timestep': 2, 'reward': -43.96143518328036, 'energy_term': -43.67932315835093, 'comfort_term': -0.2821120249294271, 'reward_weight': 0.5, 'abs_energy_penalty': -87.35864631670186, 'abs_comfort_penalty': -0.5642240498588542, 'total_power_demand': 87.35864631670186, 'total_temperature_violation': 0.5642240498588542}
# Reward:  -1647162.4758213712 {'time_elapsed(hours)': 745.1428571428571, 'month': 2, 'day': 1, 'hour': 0, 'is_raining': False, 'action': array([21.19797 , 24.966215], dtype=float32), 'timestep': 745, 'reward': -1142.6759951764916, 'energy_term': -1142.5585658891466, 'comfort_term': -0.11742928734507352, 'reward_weight': 0.5, 'abs_energy_penalty': -2285.1171317782932, 'abs_comfort_penalty': -0.23485857469014704, 'total_power_demand': 2285.1171317782932, 'total_temperature_violation': 0.23485857469014704}
# Reward:  -2785594.318273273 {'time_elapsed(hours)': 1417.2, 'month': 3, 'day': 1, 'hour': 0, 'is_raining': False, 'action': array([18.914547, 23.774359], dtype=float32), 'timestep': 1417, 'reward': -43.67932315835093, 'energy_term': -43.67932315835093, 'comfort_term': 0.0, 'reward_weight': 0.5, 'abs_energy_penalty': -87.35864631670186, 'abs_comfort_penalty': 0, 'total_power_demand': 87.35864631670186, 'total_temperature_violation': 0.0}

# %% [markdown]
# As always, remember to close the environment once the interaction is complete:

# %%
env.close()
# Out:
# [ENVIRONMENT] (INFO) : Environment closed. [demo-v1]

# %% [markdown]
# Now, let's examine the final rewards:

# %%
print(
    'Mean reward: ',
    np.mean(rewards),
    'Cumulative reward: ',
    sum(rewards))
# Out:
# Mean reward:  -1939.5689978057765 Cumulative reward:  -2792979.3568403176

# %% [markdown]
# Sinergym has an extensive [list of registered environments](https://github.com/ugr-sail/sinergym/blob/main/sinergym/__init__.py). We utilize building files with varying characteristics, such as continuous or discrete action spaces, different weather types, weather noise, run periods, timesteps, reward functions, and more. We'll explore these in the upcoming notebooks.
