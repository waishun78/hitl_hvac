# %%
# import math
# import random
# import matplotlib
# import matplotlib.pyplot as plt
# from collections import namedtuple, deque
# import numpy as np

# import torch
# import torch.nn as nn
# import torch.optim as optim
# import torch.nn.functional as F

# from simulation import Simulation

# # set up matplotlib
# is_ipython = 'inline' in matplotlib.get_backend()
# if is_ipython:
#     from IPython import display

# plt.ion()

# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward'))

# class ReplayMemory(object):
#     def __init__(self, capacity):
#         self.memory = deque([], maxlen=capacity)
#     def push(self, *args):
#         self.memory.append(Transition(*args))
#     def sample(self, batch_size):
#         return random.sample(self.memory, batch_size)
#     def __len__(self):
#         return len(self.memory)

# model_complexity = 256
# class DQN(nn.Module):
#     def __init__(self, n_observations, n_actions):
#         super(DQN, self).__init__()
#         self.layer1 = nn.Linear(n_observations, model_complexity)
#         self.layer2 = nn.Linear(model_complexity, model_complexity)
#         self.layer4 = nn.Linear(model_complexity, n_actions)
#     def forward(self, x):
#         x = F.relu(self.layer1(x))
#         x = F.relu(self.layer2(x))
#         return self.layer4(x)

# class ActionSpace():
#     def __init__(self):
#         self.true_action_space = np.round(np.arange(20, 28, 0.2), 2)
#         self.action_space = np.arange(0, len(self.true_action_space), 1) 
#         self.n = len(self.action_space)
#     def convert(self, n):
#         return self.true_action_space[n]
#     def sample(self):
#         return round(self.action_space[np.random.randint(0, self.n)], 2)

# action_space = ActionSpace()

# BATCH_SIZE = 128
# GAMMA = 0.99
# EPS_START = 0.9
# EPS_END = 0.05
# EPS_DECAY = 2000
# TAU = 0.005
# LR = 1e-4

# policy_net_1 = None
# policy_net_2 = None
# target_net = None
# optimizer = None
# memory = ReplayMemory(100000)

# steps_done = 0

# def majority_voting(action1, action2):
#     action_counts = {}
#     for action in [action1.item(), action2.item()]:
#         if action in action_counts:
#             action_counts[action] += 1
#         else:
#             action_counts[action] = 1
#     return max(action_counts, key=action_counts.get)

# def boltzmann_addition(state):
#     with torch.no_grad():
#         action_probs1 = F.softmax(policy_net_1(state), dim=1)
#         action_probs2 = F.softmax(policy_net_2(state), dim=1)
#         action_probs = action_probs1 + action_probs2
#         return action_probs.max(1)[1].view(1, 1)

# def select_action(state, strategy="averaging"):
#     global steps_done
#     sample = random.random()
#     eps_threshold = EPS_END + (EPS_START - EPS_END) * \
#         math.exp(-1. * steps_done / EPS_DECAY)
#     steps_done += 1
#     if sample > eps_threshold:
#         with torch.no_grad():
#             if strategy == "averaging":
#                 action1 = policy_net_1(state).max(1)[1].view(1, 1)
#                 action2 = policy_net_2(state).max(1)[1].view(1, 1)
#                 action = (action1 + action2) // 2  # average the actions from the two models
#             elif strategy == "majority_voting":
#                 action1 = policy_net_1(state).max(1)[1].view(1, 1)
#                 action2 = policy_net_2(state).max(1)[1].view(1, 1)
#                 action = torch.tensor([[majority_voting(action1, action2)]], device=device, dtype=torch.long)
#             elif strategy == "boltzmann_addition":
#                 action = boltzmann_addition(state)
#             else:
#                 raise ValueError("Invalid strategy. Choose from 'averaging', 'majority_voting', 'boltzmann_addition'.")
#             return action
#     else:
#         return torch.tensor([[action_space.sample()]], device=device, dtype=torch.long)

# ensemble_rl_rsts = []

# #ensemble techniques?
# def majority_voting(action1, action2):
#     action_counts = {}
#     for action in [action1.item(), action2.item()]:  # count actions
#         if action in action_counts:
#             action_counts[action] += 1
#         else:
#             action_counts[action] = 1
#     return max(action_counts, key=action_counts.get)  # return action with max votes

# def boltzmann_addition(state):
#     with torch.no_grad():
#         action_probs1 = F.softmax(policy_net_1(state), dim=1)  # adding softmax
#         action_probs2 = F.softmax(policy_net_2(state), dim=1)  
#         action_probs = action_probs1 + action_probs2  
#         return action_probs.max(1)[1].view(1, 1)  # return action with max probability

# def plot_durations(show_result=False):
#     plt.figure(1)
#     if not show_result:
#         plt.clf()
#     plt.xlabel('Episode', fontsize=14)
#     plt.ylabel('Daily Cumulative Reward', fontsize=14)
#     plt.plot(ensemble_rl_rsts)
#     plt.legend(["Ensemble RL Policy"])
#     plt.pause(0.001)
#     if is_ipython:
#         if not show_result:
#             display.display(plt.gcf())
#             display.clear_output(wait=True)
#         else:
#             display.display(plt.gcf())

# def optimize_model():
#     if len(memory) < BATCH_SIZE:
#         return
#     transitions = memory.sample(BATCH_SIZE)
#     batch = Transition(*zip(*transitions))
#     non_final_mask = torch.tensor(tuple(map(lambda s: s is not None, batch.next_state)), device=device, dtype=torch.bool)
#     non_final_next_states = torch.cat([s for s in batch.next_state if s is not None])
#     state_batch = torch.cat(batch.state)
#     action_batch = torch.cat(batch.action)
#     reward_batch = torch.cat(batch.reward)
#     state_action_values = policy_net_1(state_batch).gather(1, action_batch)
#     next_state_values = torch.zeros(BATCH_SIZE, device=device)
#     with torch.no_grad():
#         next_state_values[non_final_mask] = target_net(non_final_next_states).max(1)[0]
#     expected_state_action_values = (next_state_values * GAMMA) + reward_batch
#     criterion = nn.SmoothL1Loss()
#     loss = criterion(state_action_values, expected_state_action_values.unsqueeze(1))
#     optimizer.zero_grad()
#     loss.backward()
#     torch.nn.utils.clip_grad_value_(policy_net_1.parameters(), 100)
#     optimizer.step()

# num_episodes = 365
# ensemble_rl_rsts = []

# class Runner():
#     def __init__(self, simulator, complexity=256, strategy="averaging"):
#         global sim, model_complexity, policy_net_1, policy_net_2, target_net, optimizer, n_actions, n_observations
#         sim = simulator
#         model_complexity = complexity
#         state = sim.reset()
#         n_observations = len(state)
#         n_actions = action_space.n
#         policy_net_1 = DQN(n_observations, n_actions).to(device)
#         policy_net_2 = DQN(n_observations, n_actions).to(device)
#         #load the pretrained models
#         policy_net_1.load_state_dict(torch.load('energy_model.pth'))
#         policy_net_2.load_state_dict(torch.load('hitl_model.pth'))
#         target_net = DQN(n_observations, n_actions).to(device)
#         target_net.load_state_dict(policy_net_1.state_dict())
#         optimizer = optim.AdamW(policy_net_1.parameters(), lr=LR, amsgrad=True)
#         self.strategy = strategy

#     def run(self):
#         for i_episode in range(num_episodes):
#             state = sim.reset()
#             state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
#             while not sim.is_terminate:
#                 #here's the ensemble
#                 action = select_action(state, strategy=self.strategy)
#                 observation, reward, done = sim.step(action_space.convert(action.item()))
#                 reward = torch.tensor([reward], device=device)
#                 next_state = torch.tensor(observation, dtype=torch.float32, device=device).unsqueeze(0)
#                 memory.push(state, action, next_state, reward)
#                 state = next_state
#                 optimize_model()
#                 target_net_state_dict = target_net.state_dict()
#                 policy_net_state_dict = policy_net_1.state_dict()
#                 for key in policy_net_state_dict:
#                     target_net_state_dict[key] = policy_net_state_dict[key] * TAU + target_net_state_dict[key] * (1 - TAU)
#                 target_net.load_state_dict(target_net_state_dict)
#             rl, _ = sim.get_cummulative_reward()
#             ensemble_rl_rsts.append(rl)
#             print(f"Episode {i_episode + 1}, Ensemble RL Reward: {rl}")
#             if i_episode % 5 == 0:
#                 plot_durations()
#         print('Complete')
#         plot_durations(show_result=True)
#         plt.ioff()
#         plt.show()
#         torch.save(policy_net_1.state_dict(), 'ensemble_model.pth')
#         return ensemble_rl_rsts

# sim = Simulation(num_days=1, is_render=False, alpha=0.8, beta=1)
# runner = Runner(simulator=sim, complexity=256, strategy="boltzmann_addition")  # can change strategy here to "mv" or "ba"
# ensemble_rl_train_rsts = runner.run()
# print("Ensemble RL Policy Rewards:", ensemble_rl_train_rsts)
# Out:
# values:  [ 0.32  0.32  0.13 -0.08  0.49  0.32  0.32  0.13  0.32  0.49  0.13  0.32
#   0.31]
# values:  [0.5  0.5  0.32 0.13 0.65 0.49 0.49 0.32 0.5  0.65 0.32 0.49 0.48]
# values:  [ 0.32  0.32  0.13 -0.08  0.49  0.32  0.32  0.13  0.32  0.49  0.13  0.32
#   0.31]
# values:  [ 0.14  0.14 -0.05 -0.28  0.33  0.15  0.15 -0.05  0.14  0.33 -0.05  0.15
#   0.14  0.14 -0.28  0.33  0.15  0.14 -0.05  0.15  0.14  0.33  0.14 -0.05
#   0.14  0.14  0.14  0.15 -0.05 -0.05 -0.05  0.14  0.14  0.14]
# values:  [0.5  0.5  0.32 0.13 0.65 0.49 0.49 0.32 0.5  0.65 0.32 0.49 0.48 0.5
#  0.13 0.65 0.49 0.48 0.32 0.49 0.48 0.65 0.5  0.32 0.5  0.48 0.48 0.49
#  0.32 0.32 0.32 0.48 0.48 0.48]
# values:  [ 0.14  0.14 -0.05 -0.28  0.33  0.15  0.15 -0.05  0.14  0.33 -0.05  0.15
#   0.14  0.14 -0.28  0.33  0.15  0.14 -0.05  0.15  0.14  0.33  0.14 -0.05
#   0.14  0.14  0.14  0.15 -0.05 -0.05 -0.05  0.14  0.14  0.14]
# values:  [ 0.14  0.14 -0.05 -0.28  0.33  0.15  0.15 -0.05  0.14  0.33 -0.05  0.15
# ...
